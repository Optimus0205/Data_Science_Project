# %% [markdown]
# <a href="https://colab.research.google.com/github/Optimus0205/Data_Science_Project/blob/main/Feature_Selection_(overview).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('/content/gurgaon_properties_missing_value_imputation.csv')
df.head()
# Out:
#   property_type                   society      sector  price  price_per_sqft  \
# 0          flat           eldeco accolade  sohna road   0.87          5963.0
# 1          flat              tulip violet   sector 69   2.00          9583.0
# 2          flat  unitech uniworld gardens   sector 47   2.40         11505.0
# 3          flat        emaar palm gardens   sector 83   1.75          9211.0
# 4          flat        vatika iris floors   sector 82   0.63          5590.0
#
#    bedRoom  bathroom balcony  floorNum   agePossession  built_up_area  \
# 0        2         2      3+      10.0  Relatively New         1131.0
# 1        4         4       2       0.0  Relatively New         1889.0
# 2        3         3      3+      10.0  Moderately Old         1888.0
# 3        3         3       3       6.0  Relatively New         1600.0
# 4        2         2      3+       2.0  Relatively New         1026.0
#
#    study room  servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
df.shape
# Out:
# (3268, 18)

# %%
train_df = df.drop(columns=['society','price_per_sqft'])
# not much important

# %%
train_df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony  floorNum  \
# 0          flat  sohna road   0.87        2         2      3+      10.0
# 1          flat   sector 69   2.00        4         4       2       0.0
# 2          flat   sector 47   2.40        3         3      3+      10.0
# 3          flat   sector 83   1.75        3         3       3       6.0
# 4          flat   sector 82   0.63        2         2      3+       2.0
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0  Relatively New         1131.0           1             0           0
# 1  Relatively New         1889.0           0             0           0
# 2  Moderately Old         1888.0           0             1           0
# 3  Relatively New         1600.0           0             1           0
# 4  Relatively New         1026.0           1             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# ...

# %%
train_df_numeric = train_df.drop(columns=['property_type', 'sector', 'balcony', 'agePossession'])    # conversion of string to float
sns.heatmap(train_df_numeric.corr())
# Out:
# <Axes: >

# %%
train_df_numeric.corr()['price'].sort_values(ascending=False)
#train_df.corr()['price'].sort_values(ascending=False)
# Out:
# price              1.000000
# built_up_area      0.746839
# bathroom           0.603987
# bedRoom            0.588053
# servant room       0.383321
# pooja room         0.313491
# store room         0.301670
# study room         0.247109
# furnishing_type    0.218768
# luxury_score       0.070598
# others            -0.014455
# floorNum          -0.095580
# Name: price, dtype: float64

# %%
# cols in question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
